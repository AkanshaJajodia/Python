# %%
print('Importing Libraries')
from urllib.request import urlopen
from bs4 import BeautifulSoup as BS
import pandas as pd
from urllib.parse import urlparse, urlsplit
from PIL import Image
print('Libraries Imorted')
# Out:
# Importing Libraries
# Libraries Imorted

# %%
# scrapping for below url
url = "http://blogs.sjsu.edu/newsroom/2020/sjsucounts-the-2020-census-guide-and-sjsu-drawing/"

try:
    page = urlopen(url)
except:
    print("Error opening the URL")

soup = BS(page, 'html.parser')

# %%
# scraping the p tag 
content = soup.find('div', {"class": "entry-content"})

article = ''
for i in content.findAll('p'):
    article = article + ' ' +  i.text

print (soup.prettify())
with open('scraped_output.txt', 'w') as file:
    file.write(article)
# Out:
# <!DOCTYPE html>
# <html lang="en-US" xmlns:addthis="http://www.addthis.com/help/api-spec" xmlns:fb="http://www.facebook.com/2008/fbml">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <title>
#    #SJSUCounts: The 2020 Census Guide | SJSU Newsroom
#   </title>
#   <link href="http://gmpg.org/xfn/11" rel="profile"/>
#   <link href="http://blogs.sjsu.edu/newsroom/xmlrpc.php" rel="pingback"/>
#   <link href="//fonts.googleapis.com" rel="dns-prefetch">
#    <link href="//s.w.org" rel="dns-prefetch">
#     <link href="//us-west-2.files.campus.edublogs.org.s3.amazonaws.com" rel="dns-prefetch"/>
#     <link href="http://blogs.sjsu.edu/newsroom/feed/" rel="alternate" title="SJSU Newsroom » Feed" type="application/rss+xml"/>
#     <link href="http://blogs.sjsu.edu/newsroom/comments/feed/" rel="alternate" title="SJSU Newsroom » Comments Feed" type="application/rss+xml"/>
#     <script type="text/javascript">
#      window._wpemojiSettings = {"baseUrl":"https:\/\/s.w.org\/images\/core\/emoji\/12.0.0-1\/72x72\/","ext":".png","svgUrl":"https:\/\/s.w.org\/images\/core\/emoji\/12.0.0-1\/svg\/","svgExt":".svg","source":{"concatemoji":"http:\/\/blogs.sjsu.edu\/newsroom\/wp-includes\/js\/wp-emoji-release.min.js?ver=5.3.4"}};
# 			!function(e,a,t){var r,n,o,i,p=a.createElement("canvas"),s=p.getContext&&p.getContext("2d");function c(e,t){var a=String.fromCharCode;s.clearRect(0,0,p.width,p.height),s.fillText(a.apply(this,e),0,0);var r=p.toDataURL();return s.clearRect(0,0,p.width,p.height),s.fillText(a.apply(this,t),0,0),r===p.toDataURL()}function l(e){if(!s||!s.fillText)return!1;switch(s.textBaseline="top",s.font="600 32px Arial",e){case"flag":return!c([127987,65039,8205,9895,65039],[127987,65039,8203,9895,65039])&&(!c([55356,56826,55356,56819],[55356,56826,8203,55356,56819])&&!c([55356,57332,56128,56423,56128,56418,56128,56421,56128,56430,56128,56423,56128,56447],[55356,57332,8203,56128,56423,8203,56128,56418,8203,56128,56421,8203,56128,56430,8203,56128,56423,8203,56128,56447]));case"emoji":return!c([55357,56424,55356,57342,8205,55358,56605,8205,55357,56424,55356,57340],[55357,56424,55356,57342,8203,55358,56605,8203,55357,56424,55356,57340])}return!1}function d(e){var t=a.createElement("script");t.src=e,t.defer=t.type="text/javascript",a.getElementsByTagName("head")[0].appendChild(t)}for(i=Array("flag","emoji"),t.supports={everything:!0,everythingExceptFlag:!0},o=0;o<i.length;o++)t.supports[i[o]]=l(i[o]),t.supports.everything=t.supports.everything&&t.supports[i[o]],"flag"!==i[o]&&(t.supports.everythingExceptFlag=t.supports.everythingExceptFlag&&t.supports[i[o]]);t.supports.everythingExceptFlag=t.supports.everythingExceptFlag&&!t.supports.flag,t.DOMReady=!1,t.readyCallback=function(){t.DOMReady=!0},t.supports.everything||(n=function(){t.readyCallback()},a.addEventListener?(a.addEventListener("DOMContentLoaded",n,!1),e.addEventListener("load",n,!1)):(e.attachEvent("onload",n),a.attachEvent("onreadystatechange",function(){"complete"===a.readyState&&t.readyCallback()})),(r=t.source||{}).concatemoji?d(r.concatemoji):r.wpemoji&&r.twemoji&&(d(r.twemoji),d(r.wpemoji)))}(window,document,window._wpemojiSettings);
#     </script>
#     <style type="text/css">
#      img.wp-smiley,
# img.emoji {
# 	display: inline !important;
# 	border: none !important;
# 	box-shadow: none !important;
# 	height: 1em !important;
# 	width: 1em !important;
# 	margin: 0 .07em !important;
# 	vertical-align: -0.1em !important;
# 	background: none !important;
# 	padding: 0 !important;
# }
#     </style>
#     <link href="http://blogs.sjsu.edu/newsroom/wp-includes/css/dist/block-library/style.min.css?ver=5.3.4" id="wp-block-library-css" media="all" rel="stylesheet" type="text/css"/>
#     <link href="http://blogs.sjsu.edu/newsroom/wp-content/mu-plugins/campus-files/plugins-mods/ultimate-branding/assets/admin-bar-public.css?ver=20150323" id="wdcab-admin-bar-css" media="all" rel="stylesheet" type="text/css"/>
#     <link href="//fonts.googleapis.com/css?family=Arimo%3A400%2C400italic%2C700%2C700italic&amp;subset=latin%2Clatin-ext" id="adaption-arimo-css" media="all" rel="stylesheet" type="text/css"/>
#     <link href="http://blogs.sjsu.edu/newsroom/wp-content/themes/adaption-wpcom/style.css?ver=20170927" id="adaption-style-css" media="all" rel="stylesheet" type="text/css"/>
#     <link href="http://blogs.sjsu.edu/newsroom/wp-content/themes/adaption-wpcom/css/genericons.css" id="genericons-css" media="all" rel="stylesheet" type="text/css"/>
#     <script src="http://blogs.sjsu.edu/newsroom/wp-includes/js/jquery/jquery.js?ver=1.12.4-wp" type="text/javascript">
#     </script>
#     <script src="http://blogs.sjsu.edu/newsroom/wp-includes/js/jquery/jquery-migrate.min.js?ver=1.4.1" type="text/javascript">
#     </script>
#     <link href="http://blogs.sjsu.edu/newsroom/wp-json/" rel="https://api.w.org/"/>
#     <link href="https://blogs.sjsu.edu/newsroom/xmlrpc.php?rsd" rel="EditURI" title="RSD" type="application/rsd+xml"/>
#     <link href="http://blogs.sjsu.edu/newsroom/wp-includes/wlwmanifest.xml" rel="wlwmanifest" type="application/wlwmanifest+xml"/>
#     <link href="http://blogs.sjsu.edu/newsroom/2020/spartan-food-pantry-celebrates-one-year-of-service-at-sjsu/" rel="prev" title="Spartan Food Pantry Celebrates One Year of Service at SJSU"/>
#     <link href="http://blogs.sjsu.edu/newsroom/2020/sjsu-takes-on-pandemics-100-years-apart/" rel="next" title="SJSU Takes on Pandemics 100 Years Apart"/>
#     <meta content="SJSU Blogs" name="generator">
#      <link href="http://blogs.sjsu.edu/newsroom/2020/sjsucounts-the-2020-census-guide-and-sjsu-drawing/" rel="canonical"/>
#      <link href="http://blogs.sjsu.edu/newsroom/?p=36610" rel="shortlink"/>
#      <link href="http://blogs.sjsu.edu/newsroom/wp-json/oembed/1.0/embed?url=http%3A%2F%2Fblogs.sjsu.edu%2Fnewsroom%2F2020%2Fsjsucounts-the-2020-census-guide-and-sjsu-drawing%2F" rel="alternate" type="application/json+oembed"/>
#      <link href="http://blogs.sjsu.edu/newsroom/wp-json/oembed/1.0/embed?url=http%3A%2F%2Fblogs.sjsu.edu%2Fnewsroom%2F2020%2Fsjsucounts-the-2020-census-guide-and-sjsu-drawing%2F&amp;format=xml" rel="alternate" type="text/xml+oembed"/>
#      <style>
#       .addthis_toolbox iframe {margin: 0 !important;}
#      </style>
#      <style id="simpler-css-style" type="text/css">
#       /* ===============
#   CUSTOM CSS SJSU Marketing and Communications // communications@sjsu.edu
#   BLOG SUPPORT SJSU Web Services // webservices@sjsu.edu
#   Author: Christina Olivas
#   Contact: christina.olivas@sjsu.edu 408-924-1167
#   Last Updated: Sept 2017
#    =============== */
#
#    /*
#     SJSU COLORS
#     - sjsu blue #0055A2
#     - sjsu gold #E5A823
#     - sjsu gray #939597
#     - sjsu light gray #D2D2D2
#     - sjsu dark gray #666666
#
#     - default body text  #666666
#     - subtitle h2 text
#     - form input borders
# 	- default p text
# 	- pre borders
# */
#
# /* FONTS */
#    @font-face {
#        font-family: 'SJSUSpartan';
#        font-style: normal;
# 	   font-weight: 100;
#        src: local('SJSUSpartan'), url(https://www.sjsu.edu/sjsuhome/fonts/sjsuspartanfont/SJSUSpartanRegular.woff) format('woff');
#
#    }
#
#    @font-face {
#        font-family: 'SJSUSpartan';
# 	   font-weight: bold;
#        src: local('SJSUSpartan'), url(https://www.sjsu.edu/sjsuhome/fonts/sjsuspartanfont/SJSUSpartanBold.woff) format('woff');
#
#    }
#
#    @font-face {
#        font-family: 'SJSUSpartan';
# 	   font-weight: italic;
#        src: local('SJSUSpartan'), url(https://www.sjsu.edu/sjsuhome/fonts/sjsuspartanfont/SJSUSpartanRegular.woff) format('woff');
#
#    }
#
# /* =======================GLOBAL======================= */
#    /*
# @media only screen and (max-width: 64.063em) {
#      #mobile-panel {
# 	   height:0px;
#      }
#  }
# */
#
#
# @media only screen and (max-width: 64.063em) {
#      .home #mobile-panel {
# 	   height:0px;
#      }
#  }
#
#
# h1, h2, h3, h4, h5, h6 {
#     margin-bottom:2px;
#     }
#
# h1 {
# 	font-weight:200;
# 	font-size: 3.5rem;
# }
#
# h2 {
#     font-size: 3rem!important;
# }
#
#     h2.site-description {
#         font-size: 2.25rem!important;
#     }
#
# h3 {
#     font-weight: 200;
#     font-size: 2.3rem;
#     line-height:1.25;
#     margin-bottom:5px;
# }
#
# hr {
# 	background-color:#cccccc;
# }
#
# .social-links ul a:before {
#     background:#939597;
#     font-size:20px;
#     }
#
# @media only screen and (max-width: 64em) {
#     .social-links ul a:before {
#         font-size:35px;
#         }
# }
#
# @media only screen and (min-width: 64.063em) {
#     body.secondary-sidebar #page {
#         width:100%;
#         }
#
# 	#content, #content:before {
# 		width:60%;
# 		border-top:120px solid #ffffff;
# 	}
#
# 	#masthead, #masthead:before {
# 		width:40%;
#         background-color:#E8E8E8;
# 	}
#
# 	#masthead:before {
# 		right:60%;
# 	}
# }
#
#
#
# @media only screen and (min-width: 64.063em) {
#     #page {
#       width: 100%;
#     }
# }
#
# @media only screen and (min-width: 90.063em) {
#   #page {
#     width: 95%;
#   }
#   body.secondary-sidebar #page {
#     width: 95%;
#   }
# }
#
#
# button, input[type="button"], input[type="reset"], input[type="submit"] {
#     border:2px solid #025BAD;
# 	background:#0055A2;
# 	color:#FFFFFF;
# 	padding:5px 10px!important;
# }
#
# button:hover, input[type="button"]:hover, input[type="reset"]:hover, input[type="submit"]:hover {
# 	background:#004788;
# 	color:#FFFFFF!important;
# }
#
#
# .wp-caption img[class*="wp-image-"] {
# 	margin:4px;
# }
#
#
# .wp-caption-text {
# 	text-align:left;
# 	padding:5px;
# 	color:#666666;
# 	line-height:19px;
# 	font-size:82%;
# }
#
# .wp-caption {
# 	padding:10px;
# 	background-color:#ffffff;
# }
#
# @media only screen and (max-width: 1200px) {
# 	.wp-caption, .wp-caption-text, .wp-caption img {
# 		width:100%!important;
# 	}
# }
#
# ::-webkit-input-placeholder {
#    color: #333333;
# }
#
# :-moz-placeholder { /* Firefox 18- */
#    color: #333333;
# }
#
# ::-moz-placeholder {  /* Firefox 19+ */
#    color: #333333;
# }
#
# :-ms-input-placeholder {
#    color: #333333;
# }
#
#
# /* =======================HEADER======================= */
#
#
# h1.site-title {
#  	font-family:'SJSUSpartan', Arimo, Helvetica, sans-serif;
# 	font-weight:400;
# 	font-size:3.75rem;
# 	letter-spacing:1px;
# }
#
# #header-image.no-header {
#     display:none;
# }
#
# .site-branding {
#    padding:40px 20px 10px;
#     }
#
# 	@media only screen and (min-width: 90.063em) {
# 		.site-branding {
# 	   	 	padding:40px 20px 10px 40px;
# 	    }
# 	}
#
#
# @media only screen and (min-width: 769px) {
#     /* Only apply the layout if the user is on a desktop / tablet */
#
# 	}
#
# @media only screen and (max-width: 64em) and (min-width: 40.063em) {
#     .hentry, .page-header {
#         padding:0px 20px 0;
#         }
# }
#
# @media only screen and (min-width: 64.063em) {
#     .page-header {
#         border-bottom:1px solid #eee;
#         }
#     .hentry, .page-header {
#         padding-bottom:0;
#         }
# 	.hentry {
# 		border-bottom:20px solid #E8E8E8;
# 	    }
#     }
#     }
#
# header.archive-header {
#     padding-top:27px;
# 	padding-bottom:10px;
#     }
#
#
# /*=======================NAVIGATION MENU=======================*/
# @media only screen and (min-width: 90.063em) {
#     .main-navigation li a {
#         padding:10px 20px;
#     }
# }
#
# #widget-link:before {
#     content: '\f431';
#     }
#
#
# /* =======================PAGES======================= */
#
# body.home h1.entry-title {
# 	border-bottom:1px solid #e2e2e2;
# 	padding-bottom:2px;
# }
#
# #comments,
# .entry-meta,
# .entry-content,
# .entry-summary,
# .entry-header,
# .entry-meta {
#   max-width: 800px;
# }
#
# #gallery-1 img {
# 	border:0!important;
# }
#
# .site-main .gallery a img {
# 	max-width:96%;
# }
#
# .wp-caption-text {
# 	padding:0 5px 15px 5px;
# }
#
#
#
# /* =======================CUSTOM FEED======================= */
#
# #todaynewsfeed h2 a {
# 	text-decoration:none;
# }
#
# #todaynewsfeed p {
# 	margin-bottom:0;
# }
#
#
# /* =======================GOOGLE FEED======================= */
#
# .gfc-resultsHeader {
# 	border:none!important;
# }
#
# .gf-result .gf-author, .gf-result .gf-spacer, .gf-result .gf-relativePublishedDate {
# 	font-size:14px;
# 	color:#797979;
# }
#
# .gfc-result .gf-title {
# 	font-size:20px;
# 	text-decoration:none;
# 	margin-top:25px;
# 	height:auto!important;
# 	overflow:visible!important;
# }
#
#
# /* =======================POSTS======================= */
#
#
# /* ================LIST STYLE ON W2A POST================ */
# .post-33776 .entry-content li {
#     margin-bottom: 5px;
# }
# /* ================END LIST STYLE ON W2A POST================ */
#
#
# .entry-content, .entry-summary {
#     padding-top:0;
#     }
#
# 	.entry-content ol, .entry-content ul {
# 		margin:0 0 20px 20px;
# 	}
#
# 	.entry-content li {
# 		margin-bottom:20px;
# 	}
#
# .entry-thumbnail {
# 	display:none;
# }
#
# .entry-meta {
#     border-bottom:none;
#     font-weight:normal;
#     }
#
# .entry-meta a {
#     color:#0055A2;
#     }
#
# .entry-top span:after {
#     color:#cccccc;
#     }
#
# /*.comments-link {
#     display:none;
#     }*/
#
# h1.entry-title a, h1.entry-title a:visited {
# 	color:#0055A2;
# }
#
# h1.entry-title a:hover {
# 	color:#00427D;
# 	text-decoration:underline;
# }
#
# .entry-content h2 {
# 	font-weight:200;
# 	font-size:2.3rem;
# 	margin-bottom:10px;
# 	margin-top:30px;
# }
#
# .format-quote .entry-content, blockquote {
# 	font-style:normal;
# 	font-size:2rem;
# }
#
# .tagcloud a, .tags-links a, .wp_widget_tag_cloud a {
#     border:2px solid #CCCCCC;
#     font-weight:normal;
#     color:#666666;
#     }
#
# @media only screen and (min-width: 64.063em) {
#     .entry-meta {
#         padding:30px 0 0px;
#         }
#
#     .entry-header, .page-title {
#         padding-top:10px;
#         }
# }
#
# @media only screen and (max-width: 64em) and (min-width: 40.063em) {
#     .entry-meta {
#         padding:0;
#         }
#     .entry-header, .page-title {
#         padding-top:10px;
# 		}
# }
#
# @media only screen and (max-width: 64em) {
# 	.entry-meta.entry-top {
# 		padding-top:30px;
# 	}
# }
#
# .tags-links {
# 	display:none;
# }
#
# h3#reply-title {
# 	color:#666666;
# }
#
#
# #respond {
# 	background:#FFFFFF;
# 	color:#666666;
# 	padding:0;
# }
#
#
# @media only screen and (min-width: 64.063em) {
# 	footer.entry-meta {
# 		margin-bottom:0;
# }
# }
#
# /* =======================SIDEBAR======================= */
#
# @media only screen and (max-width: 64em) {
#
# #masthead,
# #secondary {
#   display: none;
# }
# }
#
# @media only screen and (max-width: 64em) {
#
# .home #masthead,
# .home #secondary {
#   display: block;
# }
# }
#
#
#
#
#
# @media only screen and (min-width: 64.063em) {
#   #secondary {
#     display: none;
#   }
# }
#
#
# 	/* =========WIDGETS========= */
#
# 		.widget-area p {
# 			font-size:115%;
# 		}
#
# 		.widget {
# 			border:none;
# 		}
#
#         h1.widget-title {
#             padding:10px 0 2px 0;
# 			font-weight:200;
# 			text-transform:none;
# 			font-size:190%;
# 			border-bottom:1px solid #CCCCCC;
# 			margin-bottom:10px;
#             }
#
#
#         .widget li {
#             padding:0 0 5px;
#             }
#         .widget a, .widget a:link {
#             color:#0055A2;
#             }
#
#         .search-form input.search-field {
#             background:#F3F3F3;
# 			border:1px solid #BBBBBB;
# 			border-radius:0;
# 			font-size:13px;
# 			text-transform:uppercase;
#             }
#
# 		@media only screen and (min-width: 90.063em) {
# 			.widget {
# 				padding:10px 40px;
# 			}
# 		}
#
# 		@media only screen and (max-width: 90.063em) {
# 			.widget {
# 				padding:10px 20px;
# 			}
# 		}
#
# 		/* ====SUBSCRIBE BY EMAIL==== */
#
#
# 		/* ====FLICKR PHOTOS==== */
#
# 		/* ====AUTHOR WIDGET==== */
#
#
# 		/* ====RSS WIDGET==== */
#
#
#
# /* =======================FOOTER======================= */
#
#
# #colophon {
# 	border-top:none;
# }
#
# footer#colophon {
# 	background:url(https://blogs.sjsu.edu/newsroom/files/2015/08/SJSU-Primary-mark_Web_Grey-2fkn7zb.png) no-repeat 20px 30px;
# }
#
# .site-info {
# 	visibility:hidden;
# 	margin-bottom:30px;
# }
#
# /* =======================ALL RED COLORS #cf000f TURNED TO SJSU BLUE #0055A2======================= */
# ::selection {
#     background: #E5A823;
#     }
#
# ::-moz-selection {
#     background: #E5A823;
#     }
#
# .main-navigation,
# .main-navigation ul ul,
# .main-navigation li a,
# .social-links ul a:hover:before,
# #mobile-panel,
# #header-image.no-header {
#   background: #0055A2;
# }
#
# #header-image.no-header {
#   border-bottom: 1px solid #004788;
# }
#
# h1.entry-title a:hover,
# a,
# a:hover,
# a:active,
# a:focus,
# .screen-reader-text:hover, .screen-reader-text:active, .screen-reader-text:focus,
# .widget a:hover,
# #colophon a:hover,
# .entry-meta a:hover,
# .comment-meta a:hover {
#     color: #0055A2;
#     }
#
# button:hover,
# input[type="button"]:hover,
# input[type="reset"]:hover,
# input[type="submit"]:hover,
# .tagcloud a:hover,
# .tags-links a:hover,
# .wp_widget_tag_cloud a:hover {
#   border: 2px solid #0055A2;
#   color: #0055A2;
# }
#
# button:focus,
# input[type="button"]:focus,
# input[type="reset"]:focus,
# input[type="submit"]:focus,
# button:active,
# input[type="button"]:active,
# input[type="reset"]:active,
# input[type="submit"]:active {
#   border: 2px solid #0055A2;
#   color: #0055A2;
# }
#
#
# .tagcloud a:hover, .tags-links a:hover, .wp_widget_tag_cloud a:hover {
#     color:#0055A2!important;
#     }
#
#
# /* =======================ALL DARK RED COLORS #a00101 TURNED TO DARKER SJSU BLUE #004788======================= */
#
# h1.site-title a:hover,
# .entry-summary a:hover,
# .entry-content a:hover {
#   color: #004788;
# }
#
# .main-navigation ul ul li a:hover,
# .main-navigation li a:hover {
#   background: #004788;
# }
#
# ol.comment-list li.bypostauthor article {
#   border-bottom: 3px solid #004788;
# }
#
#
#
# /*===================ADMINISTRATION PAGE==========================*/
# .headshot {
#     float:left;
# 	width:33%;
# 	clear:both;
# }
#
# .bio {
# 	float:right;
# 	width:63%;
# 	font-size:105%;
# 	line-height:160%;
# 	margin-bottom:50px;
# }
#
# @media only screen and (max-width: 500px) {
# 	.headshot {
# 		float:none;
# 		width:100%;
# 	}
#
# 	.bio {
# 		float:none;
# 		width:100%;
# 		font-size:140%;
# 		line-height:160%;
# 	}
#
# }
#
# .label {
# 	font-size:80%;
# 	text-transform:uppercase;
# 	letter-spacing:.02em;
# }
#
# .label-section {
# 	margin-bottom:5px;
# }
#
# button, input[type="button"], input[type="reset"], input[type="submit"] {
#     border:2px solid #025BAD;
#     background:#0055A2;
# 	color:#FFFFFF;
# 	padding:5px 10px!important;
# }
#
# button:hover, input[type="button"]:hover, input[type="reset"]:hover, input[type="submit"]:hover {
# 	background:#004788;
# 	color:#FFFFFF!important;
# }
#
# a.button {
#     border:1px solid #CCCCCC;
# 	font-weight:normal;
# 	border-radius:2px;
# 	color:#0055A2;
# 	font-size:15px;
# 	display:inline-block;
# 	padding:3px 15px;
# 	margin:0px 0px 5px 10px;
# 	background-color:#E8E8E8;
# 	text-decoration:none;
# 	letter-spacing:.01em;
# }
#
# @media only screen and (max-width: 500px) {
# 	a.button {
# 		display:block;
# 		margin-left:0px;
# 	}
# }
#
# button:hover,
# input[type="button"]:hover,
# input[type="reset"]:hover,
# input[type="submit"]:hover,
# .tagcloud a:hover,
# .tags-links a:hover,
# .wp_widget_tag_cloud a:hover {
#   border: 1px solid #0055A2;
#   color: #0055A2;
# }
#
# button:focus,
# input[type="button"]:focus,
# input[type="reset"]:focus,
# input[type="submit"]:focus,
# button:active,
# input[type="button"]:active,
# input[type="reset"]:active,
# input[type="submit"]:active {
#   border: 2px solid #0055A2;
#   color: #0055A2;
# }
#      </style>
#      <!-- end of custom css -->
#      <link href="https://cpb-us-w2.wpmucdn.com/blogs.sjsu.edu/dist/favicon/favicon.png" rel="shortcut icon"/>
#      <!-- Google Analytics tracking code output by Beehive Analytics Pro https://premium.wpmudev.org/project/google-analytics-for-wordpress-mu-sitewide-and-single-blog-solution/ -->
#      <script type="text/javascript">
#       ( function( i, s, o, g, r, a, m ) {
# 		i[ 'GoogleAnalyticsObject' ] = r;
# 		i[ r ] = i[ r ] || function() {
# 			( i[ r ].q = i[ r ].q || [] ).push( arguments )
# 		}, i[ r ].l = 1 * new Date();
# 		a = s.createElement( o ),
# 			m = s.getElementsByTagName( o )[ 0 ];
# 		a.async = 1;
# 		a.src = g;
# 		m.parentNode.insertBefore( a, m )
# 	} )( window, document, 'script', '//www.google-analytics.com/analytics.js', 'gaplusu' );
#
# 	function beehive_ga_track() {
# 		gaplusu( 'create', 'UA-21659030-3', 'auto' ); // Create network tracking.
# 		gaplusu( 'send', 'pageview' ); // Send pageview.
# 		gaplusu( 'create', 'UA-36740312-1', 'auto', { 'name': 'single' } ); // Create single site tracking.
# 		gaplusu( 'single.send', 'pageview' ); // Send pageview.
# 	}
#
# 	beehive_ga_track(); // Load tracking.
#      </script>
#      <!-- End Google Analytics -->
#      <style type="text/css">
#       /* <![CDATA[ */
# img.latex { vertical-align: middle; border: none; }
# /* ]]> */
#      </style>
#      <style id="custom-background-css" type="text/css">
#       body.custom-background { background-color: #e5a823; }
#      </style>
#      <style id="wp-custom-css" type="text/css">
#       @font-face {
#        font-family: 'SJSUSpartan';
#        font-style: normal;
# 	   font-weight: 100;
#        src: local('SJSUSpartan'), url(https://www.sjsu.edu/sjsuhome/fonts/sjsuspartanfont/SJSUSpartanRegular.woff) format('woff');
#
#    }
#
# @font-face {
#        font-family: 'SJSUSpartan';
# 	   font-weight: bold;
#        src: local('SJSUSpartan'), url(https://www.sjsu.edu/sjsuhome/fonts/sjsuspartanfont/SJSUSpartanBold.woff) format('woff');
#
#    }
#
# @font-face {
#        font-family: 'SJSUSpartan';
# 	   font-weight: italic;
#        src: local('SJSUSpartan'), url(https://www.sjsu.edu/sjsuhome/fonts/sjsuspartanfont/SJSUSpartanRegular.woff) format('woff');
#
#    }
#
# h1.site-title {
#  	font-family:'SJSUSpartan', Arimo, Helvetica, sans-serif;
# 	font-weight:400;
# 	font-size:3.75rem;
# 	letter-spacing:1px;
# }
#      </style>
#      <style type="text/css">
#       #wp-admin-bar-abm-login{display:block!important}body .wp-video-shortcode video,body video.wp-video-shortcode{margin:0;padding:0;background:0 0;border:none;box-shadow:none;min-width:0;height:auto;min-height:0}.screen-reader-text:not(button){clip:rect(1px,1px,1px,1px);position:absolute!important;height:1px;width:1px;overflow:hidden}
#      </style>
#     </meta>
#    </link>
#   </link>
#  </head>
#  <body class="post-template-default single single-post postid-36610 single-format-standard custom-background group-blog">
#   <div class="hfeed site" id="page">
#    <div id="mobile-panel">
#     <div id="mobile-link">
#     </div>
#     <!-- #mobile-link -->
#     <div id="widget-link">
#     </div>
#     <!-- #widget-link -->
#     <h1 class="site-title">
#      <a href="http://blogs.sjsu.edu/newsroom/" rel="home">
#       SJSU Newsroom
#      </a>
#     </h1>
#    </div>
#    <div id="panel-block">
#     <div id="mobile-block">
#      <nav class="main-navigation" id="site-navigation" role="navigation">
#       <a class="skip-link screen-reader-text" href="#content">
#        Skip to content
#       </a>
#      </nav>
#      <!-- #site-navigation .main-navigation -->
#     </div>
#     <!-- #mobile-block-->
#     <div id="widget-block">
#      <div class="widget-areas">
#       <div class="widget-area">
#        <aside class="widget widget_search" id="search-4">
#         <form action="http://blogs.sjsu.edu/newsroom/" class="search-form" method="get" role="search">
#          <label>
#           <span class="screen-reader-text">
#            Search for:
#           </span>
#           <input class="search-field" name="s" placeholder="Search …" type="search" value=""/>
#          </label>
#          <input class="search-submit" type="submit" value="Search"/>
#         </form>
#        </aside>
#        <aside class="widget widget_text" id="text-10">
#         <h1 class="widget-title">
#          Contacts
#         </h1>
#         <div class="textwidget">
#          <p>
#           <span style="font-size:120%;">
#            <strong>
#             Kenneth Mashinchi
#            </strong>
#            , Senior Director of Media Relations
#           </span>
#           <br/>
#           408-924-1167
#           <br/>
#           ken.mashinchi@sjsu.edu
#          </p>
#          <p>
#           <span style="font-size:120%;">
#            <strong>
#             Robin McElhatton
#            </strong>
#            , Media Relations Specialist
#           </span>
#           <br/>
#           408-924-1749
#           <br/>
#           robin.mcelhatton@sjsu.edu
#          </p>
#          <p>
#           <a href="http://blogs.sjsu.edu/newsroom/media-relations/ ">
#            More contacts
#           </a>
#          </p>
#         </div>
#        </aside>
#        <aside class="widget widget_text" id="text-14">
#         <h1 class="widget-title">
#          Visit
#         </h1>
#         <div class="textwidget">
#          <p>
#           <span style="font-size:120%;">
#            <a href="http://www.sjsu.edu/map/">
#             Campus Map
#            </a>
#            <br/>
#            <a href="http://www.sjsu.edu/parking/maps/garages/index.html">
#             Parking Garages
#            </a>
#            <br/>
#            <a href="http://www.sjsu.edu/map/directions/">
#             Directions to Campus
#            </a>
#            <br/>
#           </span>
#          </p>
#         </div>
#        </aside>
#        <aside class="widget widget_text" id="text-15">
#         <h1 class="widget-title">
#          Resources
#         </h1>
#         <div class="textwidget">
#          <p>
#           <span style="font-size:120%;">
#            <a href="http://blogs.sjsu.edu/experts/">
#             Experts
#            </a>
#            <br/>
#            <a href="http://blogs.sjsu.edu/newsroom/photos/">
#             Photos
#            </a>
#            <br/>
#            <a href="http://www.sjsu.edu/about_sjsu/facts_and_figures/index.html">
#             Facts
#            </a>
#            <br/>
#           </span>
#          </p>
#         </div>
#        </aside>
#        <aside class="widget widget_text" id="text-16">
#         <h1 class="widget-title">
#          Leadership
#         </h1>
#         <div class="textwidget">
#          <p>
#           <span style="font-size:120%;">
#            <a href="http://blogs.sjsu.edu/newsroom/category/for-mary-papazians-campus-messages/">
#             President's Messages
#            </a>
#            <br/>
#            <a href="http://blogs.sjsu.edu/newsroom/administration/">
#             Administration
#            </a>
#            <br/>
#           </span>
#          </p>
#         </div>
#        </aside>
#        <aside class="widget widget_text" id="text-13">
#         <h1 class="widget-title">
#          Data
#         </h1>
#         <div class="textwidget">
#          <p>
#           <span style="font-size:120%;">
#            <a href="http://www.iea.sjsu.edu/">
#             Demographics
#            </a>
#            <br/>
#            <a href="http://www.sjsu.edu/finance/about_us/budget/budget_reports/">
#             Budget
#            </a>
#            <br/>
#            <a href="http://www.sjsu.edu/police/crime_reporting/safety_report/">
#             Crime
#            </a>
#           </span>
#          </p>
#         </div>
#        </aside>
#        <aside class="widget widget_archive" id="archives-3">
#         <h1 class="widget-title">
#          News Archives
#         </h1>
#         <label class="screen-reader-text" for="archives-dropdown-3">
#          News Archives
#         </label>
#         <select id="archives-dropdown-3" name="archive-dropdown">
#          <option value="">
#           Select Month
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2020/06/">
#           June 2020
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2020/05/">
#           May 2020
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2020/04/">
#           April 2020
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2020/03/">
#           March 2020
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2020/02/">
#           February 2020
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2020/01/">
#           January 2020
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2019/12/">
#           December 2019
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2019/11/">
#           November 2019
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2019/10/">
#           October 2019
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2019/09/">
#           September 2019
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2019/08/">
#           August 2019
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2019/07/">
#           July 2019
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2019/06/">
#           June 2019
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2019/05/">
#           May 2019
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2019/04/">
#           April 2019
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2019/03/">
#           March 2019
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2019/02/">
#           February 2019
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2019/01/">
#           January 2019
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2018/12/">
#           December 2018
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2018/11/">
#           November 2018
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2018/10/">
#           October 2018
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2018/09/">
#           September 2018
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2018/08/">
#           August 2018
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2018/07/">
#           July 2018
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2018/06/">
#           June 2018
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2018/05/">
#           May 2018
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2018/04/">
#           April 2018
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2018/03/">
#           March 2018
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2018/02/">
#           February 2018
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2018/01/">
#           January 2018
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2017/11/">
#           November 2017
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2017/10/">
#           October 2017
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2017/09/">
#           September 2017
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2017/08/">
#           August 2017
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2017/07/">
#           July 2017
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2017/05/">
#           May 2017
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2017/04/">
#           April 2017
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2017/03/">
#           March 2017
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2017/02/">
#           February 2017
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2017/01/">
#           January 2017
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2016/12/">
#           December 2016
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2016/11/">
#           November 2016
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2016/10/">
#           October 2016
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2016/09/">
#           September 2016
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2016/08/">
#           August 2016
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2016/07/">
#           July 2016
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2016/06/">
#           June 2016
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2016/05/">
#           May 2016
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2016/04/">
#           April 2016
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2016/03/">
#           March 2016
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2016/02/">
#           February 2016
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2016/01/">
#           January 2016
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2015/12/">
#           December 2015
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2015/11/">
#           November 2015
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2015/10/">
#           October 2015
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2015/09/">
#           September 2015
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2015/08/">
#           August 2015
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2015/07/">
#           July 2015
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2015/06/">
#           June 2015
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2015/05/">
#           May 2015
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2015/04/">
#           April 2015
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2015/03/">
#           March 2015
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2015/02/">
#           February 2015
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2015/01/">
#           January 2015
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2014/12/">
#           December 2014
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2014/11/">
#           November 2014
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2014/10/">
#           October 2014
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2014/09/">
#           September 2014
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2014/08/">
#           August 2014
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2014/07/">
#           July 2014
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2014/06/">
#           June 2014
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2014/05/">
#           May 2014
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2014/04/">
#           April 2014
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2014/03/">
#           March 2014
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2014/02/">
#           February 2014
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2014/01/">
#           January 2014
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2013/12/">
#           December 2013
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2013/11/">
#           November 2013
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2013/10/">
#           October 2013
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2013/09/">
#           September 2013
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2013/08/">
#           August 2013
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2013/07/">
#           July 2013
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2013/06/">
#           June 2013
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2013/05/">
#           May 2013
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2013/04/">
#           April 2013
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2013/03/">
#           March 2013
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2013/02/">
#           February 2013
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2013/01/">
#           January 2013
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2012/12/">
#           December 2012
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2012/11/">
#           November 2012
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2012/10/">
#           October 2012
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2012/09/">
#           September 2012
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2012/08/">
#           August 2012
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2012/07/">
#           July 2012
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2012/06/">
#           June 2012
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2012/05/">
#           May 2012
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2012/04/">
#           April 2012
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2012/03/">
#           March 2012
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2012/02/">
#           February 2012
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2012/01/">
#           January 2012
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2011/12/">
#           December 2011
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2011/11/">
#           November 2011
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2011/10/">
#           October 2011
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2011/09/">
#           September 2011
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2011/08/">
#           August 2011
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2011/07/">
#           July 2011
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2011/06/">
#           June 2011
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2011/05/">
#           May 2011
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2011/04/">
#           April 2011
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2011/03/">
#           March 2011
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2011/02/">
#           February 2011
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2011/01/">
#           January 2011
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2010/12/">
#           December 2010
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2010/11/">
#           November 2010
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2010/10/">
#           October 2010
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2010/09/">
#           September 2010
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2010/08/">
#           August 2010
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2010/05/">
#           May 2010
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2010/04/">
#           April 2010
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2010/03/">
#           March 2010
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2010/02/">
#           February 2010
#          </option>
#          <option value="http://blogs.sjsu.edu/newsroom/2010/01/">
#           January 2010
#          </option>
#         </select>
#         <script type="text/javascript">
#          /* <![CDATA[ */
# (function() {
# 	var dropdown = document.getElementById( "archives-dropdown-3" );
# 	function onSelectChange() {
# 		if ( dropdown.options[ dropdown.selectedIndex ].value !== '' ) {
# 			document.location.href = this.options[ this.selectedIndex ].value;
# 		}
# 	}
# 	dropdown.onchange = onSelectChange;
# })();
# /* ]]> */
#         </script>
#        </aside>
#        <aside class="widget widget_text" id="text-12">
#         <div class="textwidget">
#          <script src="http://stage.sjsu.edu/sjsuhome/includes/js-sjsunewsroom/newsroomfeed.js" type="text/javascript">
#          </script>
#         </div>
#        </aside>
#       </div>
#       <!-- .widget-area -->
#      </div>
#      <!-- .widgets-areas -->
#      <div class="widget-areas">
#      </div>
#      <!-- .widgets-areas -->
#     </div>
#     <!-- #widget-block-->
#    </div>
#    <header class="panel" id="masthead" role="banner">
#     <div class="no-header" id="header-image">
#     </div>
#     <!-- #header-image .no-header -->
#     <div class="site-branding">
#      <h1 class="site-title">
#       <a href="http://blogs.sjsu.edu/newsroom/" rel="home">
#        SJSU Newsroom
#       </a>
#      </h1>
#      <h2 class="site-description">
#       San Jose State's Official News Source
#      </h2>
#     </div>
#     <!-- .site-branding -->
#     <nav class="main-navigation" id="site-navigation" role="navigation">
#      <a class="skip-link screen-reader-text" href="#content">
#       Skip to content
#      </a>
#     </nav>
#     <!-- #site-navigation .main-navigation -->
#     <div class="widget-areas">
#      <div class="widget-area">
#       <aside class="widget widget_search" id="search-4">
#        <form action="http://blogs.sjsu.edu/newsroom/" class="search-form" method="get" role="search">
#         <label>
#          <span class="screen-reader-text">
#           Search for:
#          </span>
#          <input class="search-field" name="s" placeholder="Search …" type="search" value=""/>
#         </label>
#         <input class="search-submit" type="submit" value="Search"/>
#        </form>
#       </aside>
#       <aside class="widget widget_text" id="text-10">
#        <h1 class="widget-title">
#         Contacts
#        </h1>
#        <div class="textwidget">
#         <p>
#          <span style="font-size:120%;">
#           <strong>
#            Kenneth Mashinchi
#           </strong>
#           , Senior Director of Media Relations
#          </span>
#          <br/>
#          408-924-1167
#          <br/>
#          ken.mashinchi@sjsu.edu
#         </p>
#         <p>
#          <span style="font-size:120%;">
#           <strong>
#            Robin McElhatton
#           </strong>
#           , Media Relations Specialist
#          </span>
#          <br/>
#          408-924-1749
#          <br/>
#          robin.mcelhatton@sjsu.edu
#         </p>
#         <p>
#          <a href="http://blogs.sjsu.edu/newsroom/media-relations/ ">
#           More contacts
#          </a>
#         </p>
#        </div>
#       </aside>
#       <aside class="widget widget_text" id="text-14">
#        <h1 class="widget-title">
#         Visit
#        </h1>
#        <div class="textwidget">
#         <p>
#          <span style="font-size:120%;">
#           <a href="http://www.sjsu.edu/map/">
#            Campus Map
#           </a>
#           <br/>
#           <a href="http://www.sjsu.edu/parking/maps/garages/index.html">
#            Parking Garages
#           </a>
#           <br/>
#           <a href="http://www.sjsu.edu/map/directions/">
#            Directions to Campus
#           </a>
#           <br/>
#          </span>
#         </p>
#        </div>
#       </aside>
#       <aside class="widget widget_text" id="text-15">
#        <h1 class="widget-title">
#         Resources
#        </h1>
#        <div class="textwidget">
#         <p>
#          <span style="font-size:120%;">
#           <a href="http://blogs.sjsu.edu/experts/">
#            Experts
#           </a>
#           <br/>
#           <a href="http://blogs.sjsu.edu/newsroom/photos/">
#            Photos
#           </a>
#           <br/>
#           <a href="http://www.sjsu.edu/about_sjsu/facts_and_figures/index.html">
#            Facts
#           </a>
#           <br/>
#          </span>
#         </p>
#        </div>
#       </aside>
#       <aside class="widget widget_text" id="text-16">
#        <h1 class="widget-title">
#         Leadership
#        </h1>
#        <div class="textwidget">
#         <p>
#          <span style="font-size:120%;">
#           <a href="http://blogs.sjsu.edu/newsroom/category/for-mary-papazians-campus-messages/">
#            President's Messages
#           </a>
#           <br/>
#           <a href="http://blogs.sjsu.edu/newsroom/administration/">
#            Administration
#           </a>
#           <br/>
#          </span>
#         </p>
#        </div>
#       </aside>
#       <aside class="widget widget_text" id="text-13">
#        <h1 class="widget-title">
#         Data
#        </h1>
#        <div class="textwidget">
#         <p>
#          <span style="font-size:120%;">
#           <a href="http://www.iea.sjsu.edu/">
#            Demographics
#           </a>
#           <br/>
#           <a href="http://www.sjsu.edu/finance/about_us/budget/budget_reports/">
#            Budget
#           </a>
#           <br/>
#           <a href="http://www.sjsu.edu/police/crime_reporting/safety_report/">
#            Crime
#           </a>
#          </span>
#         </p>
#        </div>
#       </aside>
#       <aside class="widget widget_archive" id="archives-3">
#        <h1 class="widget-title">
#         News Archives
#        </h1>
#        <label class="screen-reader-text" for="archives-dropdown-3">
#         News Archives
#        </label>
#        <select id="archives-dropdown-3" name="archive-dropdown">
#         <option value="">
#          Select Month
#         </option>
#         <option value="http://blogs.sjsu.edu/newsroom/2020/06/">
#          June 2020
#         </option>
#         <option value="http://blogs.sjsu.edu/newsroom/2020/05/">
#          May 2020
#         </option>
#         <option value="http://blogs.sjsu.edu/newsroom/2020/04/">
#          April 2020
#         </option>
#         <option value="http://blogs.sjsu.edu/newsroom/2020/03/">
#          March 2020
#         </option>
#         <option value="http://blogs.sjsu.edu/newsroom/2020/02/">
#          February 2020
#         </option>
#         <option value="http://blogs.sjsu.edu/newsroom/2020/01/">
#          January 2020
#         </option>
#         <option value="http://blogs.sjsu.edu/newsroom/2019/12/">
#          December 2019
#         </option>
#         <option value="http://blogs.sjsu.edu/newsroom/2019/11/">
#          November 2019
#         </option>
#         <option value="http://blogs.sjsu.edu/newsroom/2019/10/">
#          October 2019
#         </option>
#         <option value="http://blogs.sjsu.edu/newsroom/2019/09/">
#          September 2019
#         </option>
#         <option value="http://blogs.sjsu.edu/newsroom/2019/08/">
#          August 2019
#         </option>
#         <option value="http://blogs.sjsu.edu/newsroom/2019/07/">
#          July 2019
#         </option>
#         <option value="http://blogs.sjsu.edu/newsroom/2019/06/">
#          June 2019
#         </option>
#         <option value="http://blogs.sjsu.edu/newsroom/2019/05/">
#          May 2019
#         </option>
#         <option value="http://blogs.sjsu.edu/newsroom/2019/04/">
#          April 2019
#         </option>
#         <option value="http://blogs.sjsu.edu/newsroom/2019/03/">
#          March 2019
#         </option>
#         <option value="http://blogs.sjsu.edu/newsroom/2019/02/">
#          February 2019
#         </option>
#         <option value="http://blogs.sjsu.edu/newsroom/2019/01/">
#          January 2019
#         </option>
#         <option value="http://blogs.sjsu.edu/newsroom/2018/12/">
#          December 2018
#         </option>
#         <option value="http://blogs.sjsu.edu/newsroom/2018/11/">
#          November 2018
#         </option>
#         <option value="http://blogs.sjsu.edu/newsroom/2018/10/">
#          October 2018
#         </option>
#         <option value="http://blogs.sjsu.edu/newsroom/2018/09/">
#          September 2018
#         </option>
#         <option value="http://blogs.sjsu.edu/newsroom/2018/08/">
#          August 2018
#         </option>
#         <option value="http://blogs.sjsu.edu/newsroom/2018/07/">
#          July 2018
#         </option>
#         <option value="http://blogs.sjsu.edu/newsroom/2018/06/">
#          June 2018
#         </option>
#         <option value="http://blogs.sjsu.edu/newsroom/2018/05/">
#          May 2018
#         </option>
# ...
#          October 2013
#         </option>
#         <option value="http://blogs.sjsu.edu/newsroom/2013/09/">
#          September 2013
#         </option>
#         <option value="http://blogs.sjsu.edu/newsroom/2013/08/">
#          August 2013
#         </option>
#         <option value="http://blogs.sjsu.edu/newsroom/2013/07/">
#          July 2013
#         </option>
#         <option value="http://blogs.sjsu.edu/newsroom/2013/06/">
#          June 2013
#         </option>
#         <option value="http://blogs.sjsu.edu/newsroom/2013/05/">
#          May 2013
#         </option>
#         <option value="http://blogs.sjsu.edu/newsroom/2013/04/">
#          April 2013
#         </option>
#         <option value="http://blogs.sjsu.edu/newsroom/2013/03/">
#          March 2013
#         </option>
#         <option value="http://blogs.sjsu.edu/newsroom/2013/02/">
#          February 2013
#         </option>
#         <option value="http://blogs.sjsu.edu/newsroom/2013/01/">
#          January 2013
#         </option>
#         <option value="http://blogs.sjsu.edu/newsroom/2012/12/">
#          December 2012
#         </option>
#         <option value="http://blogs.sjsu.edu/newsroom/2012/11/">
#          November 2012
#         </option>
#         <option value="http://blogs.sjsu.edu/newsroom/2012/10/">
#          October 2012
#         </option>
#         <option value="http://blogs.sjsu.edu/newsroom/2012/09/">
#          September 2012
#         </option>
#         <option value="http://blogs.sjsu.edu/newsroom/2012/08/">
#          August 2012
#         </option>
#         <option value="http://blogs.sjsu.edu/newsroom/2012/07/">
#          July 2012
#         </option>
#         <option value="http://blogs.sjsu.edu/newsroom/2012/06/">
#          June 2012
#         </option>
#         <option value="http://blogs.sjsu.edu/newsroom/2012/05/">
#          May 2012
#         </option>
#         <option value="http://blogs.sjsu.edu/newsroom/2012/04/">
#          April 2012
#         </option>
#         <option value="http://blogs.sjsu.edu/newsroom/2012/03/">
#          March 2012
#         </option>
#         <option value="http://blogs.sjsu.edu/newsroom/2012/02/">
#          February 2012
#         </option>
#         <option value="http://blogs.sjsu.edu/newsroom/2012/01/">
#          January 2012
#         </option>
#         <option value="http://blogs.sjsu.edu/newsroom/2011/12/">
#          December 2011
#         </option>
#         <option value="http://blogs.sjsu.edu/newsroom/2011/11/">
#          November 2011
#         </option>
#         <option value="http://blogs.sjsu.edu/newsroom/2011/10/">
#          October 2011
#         </option>
#         <option value="http://blogs.sjsu.edu/newsroom/2011/09/">
#          September 2011
#         </option>
#         <option value="http://blogs.sjsu.edu/newsroom/2011/08/">
#          August 2011
#         </option>
#         <option value="http://blogs.sjsu.edu/newsroom/2011/07/">
#          July 2011
#         </option>
#         <option value="http://blogs.sjsu.edu/newsroom/2011/06/">
#          June 2011
#         </option>
#         <option value="http://blogs.sjsu.edu/newsroom/2011/05/">
#          May 2011
#         </option>
#         <option value="http://blogs.sjsu.edu/newsroom/2011/04/">
#          April 2011
#         </option>
#         <option value="http://blogs.sjsu.edu/newsroom/2011/03/">
#          March 2011
#         </option>
#         <option value="http://blogs.sjsu.edu/newsroom/2011/02/">
#          February 2011
#         </option>
#         <option value="http://blogs.sjsu.edu/newsroom/2011/01/">
#          January 2011
#         </option>
#         <option value="http://blogs.sjsu.edu/newsroom/2010/12/">
#          December 2010
#         </option>
#         <option value="http://blogs.sjsu.edu/newsroom/2010/11/">
#          November 2010
#         </option>
#         <option value="http://blogs.sjsu.edu/newsroom/2010/10/">
#          October 2010
#         </option>
#         <option value="http://blogs.sjsu.edu/newsroom/2010/09/">
#          September 2010
#         </option>
#         <option value="http://blogs.sjsu.edu/newsroom/2010/08/">
#          August 2010
#         </option>
#         <option value="http://blogs.sjsu.edu/newsroom/2010/05/">
#          May 2010
#         </option>
#         <option value="http://blogs.sjsu.edu/newsroom/2010/04/">
#          April 2010
#         </option>
#         <option value="http://blogs.sjsu.edu/newsroom/2010/03/">
#          March 2010
#         </option>
#         <option value="http://blogs.sjsu.edu/newsroom/2010/02/">
#          February 2010
#         </option>
#         <option value="http://blogs.sjsu.edu/newsroom/2010/01/">
#          January 2010
#         </option>
#        </select>
#        <script type="text/javascript">
#         /* <![CDATA[ */
# (function() {
# 	var dropdown = document.getElementById( "archives-dropdown-3" );
# 	function onSelectChange() {
# 		if ( dropdown.options[ dropdown.selectedIndex ].value !== '' ) {
# 			document.location.href = this.options[ this.selectedIndex ].value;
# 		}
# 	}
# 	dropdown.onchange = onSelectChange;
# })();
# /* ]]> */
#        </script>
#       </aside>
#       <aside class="widget widget_text" id="text-12">
#        <div class="textwidget">
#         <script src="http://stage.sjsu.edu/sjsuhome/includes/js-sjsunewsroom/newsroomfeed.js" type="text/javascript">
#         </script>
#        </div>
#       </aside>
#      </div>
#      <!-- .widget-area -->
#     </div>
#     <!-- .widgets-areas -->
#    </header>
#    <!-- #masthead .site-header -->
#    <div class="site-content" id="content">
#     <div class="content-area" id="primary">
#      <main class="site-main" id="main" role="main">
#       <article class="post-36610 post type-post status-publish format-standard hentry category-news-2 tag-census tag-raffle" id="post-36610">
#        <div class="entry-meta entry-top">
#         <span class="posted-on">
#          Posted on
#          <a href="http://blogs.sjsu.edu/newsroom/2020/sjsucounts-the-2020-census-guide-and-sjsu-drawing/" rel="bookmark">
#           <time class="entry-date published" datetime="2020-03-26T15:17:53-08:00">
#            March 26, 2020
#           </time>
#           <time class="updated" datetime="2020-04-23T14:20:23-08:00">
#            April 23, 2020
#           </time>
#          </a>
#         </span>
#         <span class="byline">
#          by
#          <span class="author vcard">
#           <a class="url fn n" href="http://blogs.sjsu.edu/newsroom/author/012055511/">
#            Julia Halprin Jackson
#           </a>
#          </span>
#         </span>
#         <span class="cat-links">
#          <a href="http://blogs.sjsu.edu/newsroom/category/news-2/" rel="category tag">
#           News
#          </a>
#         </span>
#        </div>
#        <!-- .entry-meta -->
#        <header class="entry-header">
#         <h1 class="entry-title">
#          #SJSUCounts: The 2020 Census Guide
#         </h1>
#        </header>
#        <!-- .entry-header -->
#        <div class="entry-content">
#         <p>
#          Starting this spring, the U.S. Census Bureau is collecting data on the number of people living in households across the country. San Jose State encourages all SJSU students to
#          <a href="https://my2020census.gov/">
#           participate in the census
#          </a>
#          for a variety of reasons. Please see below for frequently asked questions about the Census.
#         </p>
#         <p style="font-size: 20px;">
#          <strong>
#           <a href="https://my2020census.gov/">
#            Fill out your 2020 Census
#           </a>
#          </strong>
#         </p>
#         <div class="wp-caption alignnone" id="attachment_36622" style="width: 855px">
#          <a href="http://blogs.sjsu.edu/newsroom/2020/sjsucounts-the-2020-census-guide-and-sjsu-drawing/stud_032520_mobile-app-tile_web/" rel="attachment wp-att-36622">
#           <img alt="#SJSUCounts Complete the California 2020 census today!" aria-describedby="caption-attachment-36622" class="size-full wp-image-36622" height="563" sizes="(max-width: 845px) 100vw, 845px" src="https://blogs.sjsu.edu/newsroom/files/2020/03/STUD_032520_Mobile-app-tile_WEB.png" srcset="http://blogs.sjsu.edu/newsroom/files/2020/03/STUD_032520_Mobile-app-tile_WEB.png 845w, http://blogs.sjsu.edu/newsroom/files/2020/03/STUD_032520_Mobile-app-tile_WEB-632x421.png 632w, http://blogs.sjsu.edu/newsroom/files/2020/03/STUD_032520_Mobile-app-tile_WEB-768x512.png 768w" width="845"/>
#          </a>
#          <p class="wp-caption-text" id="caption-attachment-36622">
#           SJSU students who complete the 2020 U.S. Census and complete an SJSU form are entered into a prize drawing.
#          </p>
#         </div>
#         <p>
#          <a href="https://blogs.sjsu.edu/newsroom/files/2020/03/STUD_032520_RewardsDrawing_02.pdf">
#           Download #SJSUCounts: Representation, Rewards, and a Drawing [pdf]
#          </a>
#         </p>
#         <p>
#          <a href="https://blogs.sjsu.edu/newsroom/files/2020/03/STUD_032520_FAQ.pdf">
#           Download #SJSUCounts: The 2020 Census Guide FAQ [pdf]
#          </a>
#         </p>
#         <h2>
#          2020 Census Guide FAQ
#         </h2>
#         <h3>
#          What is the 2020 Census?
#         </h3>
#         <p>
#          Every 10 years, the U.S. Census Bureau counts every person living in the U.S. as mandated in the Constitution. The count begins in mid-March and lasts through the summer.
#         </p>
#         <h3>
#          Why does the 2020 Census matter?
#         </h3>
#         <p>
#          For every person left uncounted, California could lose up to $1,000 per person each year for the next ten years. Completing your Census form helps ensure California receives funding for healthcare services, parks and roads that support your local community.
#         </p>
#         <h3>
#          What questions are on the 2020 Census?
#         </h3>
#         <p>
#          The Census is a simple and confidential
#          <a href="https://2020census.gov/en/about-questions.html">
#           9-question survey
#          </a>
#          that takes less than 5 minutes to complete. Questions include your name, address, gender, race, and age. The 2020 Census does not ask about your citizenship status or for your social security number, bank details, payment, or a donation.
#         </p>
#         <h3>
#          How should I complete the questions on residence?
#         </h3>
#         <p>
#          In general, count yourself at the U.S. residence where you live and sleep most of the time.
#         </p>
#         <h4>
#          Tips on the Residence Question for Students
#         </h4>
#         <ul>
#          <li>
#           <strong>
#            Students who usually live in University Housing.
#           </strong>
#           Count yourself at SJSU, even if you are temporarily living elsewhere due to the COVID-19 pandemic.
#          </li>
#          <li>
#           <strong>
#            International and undocumented students.
#           </strong>
#           Count yourself at the U.S. residence where you live and sleep most of the time.
#          </li>
#          <li>
#           <strong>
#            Students enrolled in study-abroad programs.
#           </strong>
#           If you are living outside the U.S. on Census Day, April 1, 2020, do not count yourself in the stateside census. If you are back in the U.S., count yourself at the U.S. residence where you live and sleep most of the time.
#          </li>
#          <li>
#           <strong>
#            Students who are homeless or housing insecure.
#           </strong>
#           If you do not have a usual residence, count yourself where you are at the time of taking the census.
#          </li>
#          <li>
#           More information available in the
#           <a href="https://docs.google.com/presentation/d/1nkszCiQuRnTD_ypxKQ-rh_xfws5xTjQRo731N_hdiDM/edit?usp=sharing">
#            SJSU Counts Overview Slides
#           </a>
#           .
#          </li>
#         </ul>
#         <!-- AddThis Button Begin -->
#         <script type="text/javascript">
#          var addthis_product = 'wpp-262';
# var addthis_config = {"data_track_clickback":true,"data_track_addressbar":false};if (typeof(addthis_share) == "undefined"){ addthis_share = [];}
#         </script>
#         <script src="//s7.addthis.com/js/250/addthis_widget.js#pubid=wp-5ef4236a40ad324b" type="text/javascript">
#         </script>
#         <div addthis:title="#SJSUCounts: The 2020 Census Guide " addthis:url="http://blogs.sjsu.edu/newsroom/2020/sjsucounts-the-2020-census-guide-and-sjsu-drawing/" class="addthis_toolbox addthis_default_style">
#          <a class="addthis_button_facebook_like" fb:like:layout="button_count">
#          </a>
#          <a class="addthis_button_tweet">
#          </a>
#          <a class="addthis_button_google_plusone" g:plusone:size="medium">
#          </a>
#          <a class="addthis_counter addthis_pill_style">
#          </a>
#         </div>
#        </div>
#        <!-- .entry-content -->
#        <footer class="entry-meta">
#         <span class="tags-links">
#          <a href="http://blogs.sjsu.edu/newsroom/tag/census/" rel="tag">
#           census
#          </a>
#          <a href="http://blogs.sjsu.edu/newsroom/tag/raffle/" rel="tag">
#           raffle
#          </a>
#         </span>
#        </footer>
#        <!-- .entry-meta -->
#       </article>
#       <!-- #post-## -->
#       <nav class="navigation post-navigation" role="navigation">
#        <h1 class="screen-reader-text">
#         Post navigation
#        </h1>
#        <div class="nav-links">
#         <div class="nav-previous">
#          <a href="http://blogs.sjsu.edu/newsroom/2020/spartan-food-pantry-celebrates-one-year-of-service-at-sjsu/" rel="prev">
#           <span class="meta-nav">
#            ←
#           </span>
#           Spartan Food Pantry Celebrates One Year of Service at SJSU
#          </a>
#         </div>
#         <div class="nav-next">
#          <a href="http://blogs.sjsu.edu/newsroom/2020/sjsu-takes-on-pandemics-100-years-apart/" rel="next">
#           SJSU Takes on Pandemics 100 Years Apart
#           <span class="meta-nav">
#            →
#           </span>
#          </a>
#         </div>
#        </div>
#        <!-- .nav-links -->
#       </nav>
#       <!-- .navigation -->
#      </main>
#      <!-- #main .site-main -->
#     </div>
#     <!-- #primary .content-area -->
#     <footer class="site-footer" id="colophon" role="contentinfo">
#      <div class="site-info">
#       <a href="http://wordpress.org/" rel="generator">
#        Proudly powered by WordPress
#       </a>
#       <span class="sep">
#        |
#       </span>
#       Theme: Adaption by
#       <a href="http://themes.wordpress.com/themes/adaption" rel="designer">
#        WordPress.com
#       </a>
#       .
#      </div>
#      <!-- .site-info -->
#     </footer>
#     <!-- #colophon .site-footer -->
#    </div>
#    <!-- #content -->
#   </div>
#   <!-- #page -->
#   <!-- AddThis Button Begin -->
#   <script type="text/javascript">
#    var addthis_product = 'wpp-262';
# var addthis_config = {"data_track_clickback":true,"data_track_addressbar":false};if (typeof(addthis_share) == "undefined"){ addthis_share = [];}
#   </script>
#   <script src="//s7.addthis.com/js/250/addthis_widget.js#pubid=wp-5ef4236a50ea5364" type="text/javascript">
#   </script>
#   <div id="global-footer-content">
#    <div id="global-footer-content-inner">
#     <script type="text/javascript">
#      (function() {
#   var didInit = false;
#   function initMunchkin() {
#     if(didInit === false) {
#       didInit = true;
#       Munchkin.init('663-UKQ-998');
#     }
#   }
#   var s = document.createElement('script');
#   s.type = 'text/javascript';
#   s.async = true;
#   s.src = '//munchkin.marketo.net/munchkin.js';
#   s.onreadystatechange = function() {
#     if (this.readyState == 'complete' || this.readyState == 'loaded') {
#       initMunchkin();
#     }
#   };
#   s.onload = initMunchkin;
#   document.getElementsByTagName('head')[0].appendChild(s);
# })();
#     </script>
#    </div>
#   </div>
#   <script src="http://blogs.sjsu.edu/newsroom/wp-content/themes/adaption-wpcom/js/skip-link-focus-fix.js?ver=20130115" type="text/javascript">
#   </script>
#   <script src="http://blogs.sjsu.edu/newsroom/wp-content/themes/adaption-wpcom/js/adaption.js?ver=20142202" type="text/javascript">
#   </script>
#   <script src="http://blogs.sjsu.edu/newsroom/wp-includes/js/wp-embed.min.js?ver=5.3.4" type="text/javascript">
#   </script>
#  </body>
# </html>
