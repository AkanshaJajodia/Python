# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '0.25.1'

# %%
pd.show_versions()
# Out:
# INSTALLED VERSIONS
# ------------------
# commit           : None
# python           : 3.7.4.final.0
# python-bits      : 64
# OS               : Darwin
# OS-release       : 18.7.0
# machine          : x86_64
# processor        : i386
# byteorder        : little
# LC_ALL           : None
# LANG             : en_US.UTF-8
# LOCALE           : en_US.UTF-8
#
# pandas           : 0.25.1
# numpy            : 1.18.1
# pytz             : 2019.3
# dateutil         : 2.8.0
# pip              : 20.0.2
# setuptools       : 41.4.0
# Cython           : 0.29.13
# pytest           : 5.2.1
# hypothesis       : None
# sphinx           : 2.2.0
# blosc            : None
# feather          : None
# xlsxwriter       : 1.2.1
# lxml.etree       : 4.4.1
# html5lib         : 1.0.1
# pymysql          : None
# psycopg2         : None
# jinja2           : 2.10.3
# IPython          : 7.8.0
# pandas_datareader: None
# bs4              : 4.8.0
# bottleneck       : 1.2.1
# fastparquet      : None
# ...

# %% [markdown]
# Reading a csv file into pandas dataframe.

# %%
df = pd.read_csv('/Users/akanshajajodia/Desktop/olympics.csv',skiprows=4)
df.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29216 entries, 0 to 29215
# Data columns (total 10 columns):
# City            29216 non-null object
# Edition         29216 non-null int64
# Sport           29216 non-null object
# Discipline      29216 non-null object
# Athlete         29216 non-null object
# NOC             29216 non-null object
# Gender          29216 non-null object
# Event           29216 non-null object
# Event_gender    29216 non-null object
# Medal           29216 non-null object
# dtypes: int64(1), object(9)
# memory usage: 2.2+ MB

# %% [markdown]
# Accessing Series/columns

# %%
df['City']
# Out:
# 0         Athens
# 1         Athens
# 2         Athens
# 3         Athens
# 4         Athens
#           ...
# 29211    Beijing
# 29212    Beijing
# 29213    Beijing
# 29214    Beijing
# 29215    Beijing
# Name: City, Length: 29216, dtype: object

# %%
df[['City','Sport']]
# Out:
#           City      Sport
# 0       Athens   Aquatics
# 1       Athens   Aquatics
# 2       Athens   Aquatics
# 3       Athens   Aquatics
# 4       Athens   Aquatics
# ...        ...        ...
# 29211  Beijing  Wrestling
# 29212  Beijing  Wrestling
# 29213  Beijing  Wrestling
# 29214  Beijing  Wrestling
# 29215  Beijing  Wrestling
#
# [29216 rows x 2 columns]

# %% [markdown]
# value_count()

# %%
df.Edition.value_counts()
# Out:
# 2008    2042
# 2000    2015
# 2004    1998
# 1996    1859
# 1992    1705
# 1988    1546
# 1984    1459
# 1980    1387
# 1976    1305
# 1920    1298
# 1972    1185
# 1968    1031
# 1964    1010
# 1952     889
# 1912     885
# 1956     885
# 1924     884
# 1960     882
# 1936     875
# 1948     814
# 1908     804
# 1928     710
# 1932     615
# 1900     512
# 1904     470
# 1896     151
# Name: Edition, dtype: int64

# %%
df.Edition.value_counts(ascending=True)
# Out:
# 1896     151
# 1904     470
# 1900     512
# 1932     615
# 1928     710
# 1908     804
# 1948     814
# 1936     875
# 1960     882
# 1924     884
# 1956     885
# 1912     885
# 1952     889
# 1964    1010
# 1968    1031
# 1972    1185
# 1920    1298
# 1976    1305
# 1980    1387
# 1984    1459
# 1988    1546
# 1992    1705
# 1996    1859
# 2004    1998
# 2000    2015
# 2008    2042
# Name: Edition, dtype: int64

# %% [markdown]
# Check how many medals were presented to each gender.

# %%
df.Gender.value_counts()
# Out:
# Men      21721
# Women     7495
# Name: Gender, dtype: int64

# %% [markdown]
# using sort_values() .. axis = 0 is sorting along column

# %%
df.Athlete.sort_values() # provides list sorted by name of athlete
# Out:
# 651                 AABYE, Edgar
# 2849       AALTONEN, Arvo Ossian
# 2852       AALTONEN, Arvo Ossian
# 7716    AALTONEN, Paavo Johannes
# 7730    AALTONEN, Paavo Johannes
#                   ...
# 603                   ÖSTMO, Ole
# 608                   ÖSTMO, Ole
# 621                   ÖSTMO, Ole
# 596                   ÖSTMO, Ole
# 8051           ÖSTRAND, Per-Olof
# Name: Athlete, Length: 29216, dtype: object

# %% [markdown]
# df.sort_values(by=['Edition','Athlete'])

# %%
df.Medal == 'Gold'
# Out:
# 0         True
# 1        False
# 2        False
# 3         True
# 4        False
#          ...
# 29211    False
# 29212    False
# 29213    False
# 29214     True
# 29215    False
# Name: Medal, Length: 29216, dtype: bool

# %%
df[df.Medal == 'Gold']
# Out:
#           City  Edition      Sport       Discipline              Athlete  NOC  \
# 0       Athens     1896   Aquatics         Swimming        HAJOS, Alfred  HUN
# 3       Athens     1896   Aquatics         Swimming   MALOKINIS, Ioannis  GRE
# 6       Athens     1896   Aquatics         Swimming        HAJOS, Alfred  HUN
# 9       Athens     1896   Aquatics         Swimming        NEUMANN, Paul  AUT
# 13      Athens     1896  Athletics        Athletics        BURKE, Thomas  USA
# ...        ...      ...        ...              ...                  ...  ...
# 29199  Beijing     2008  Wrestling  Wrestling Gre-R       GUENOT, Steeve  FRA
# 29203  Beijing     2008  Wrestling  Wrestling Gre-R  KVIRKELIA, Manuchar  GEO
# 29206  Beijing     2008  Wrestling  Wrestling Gre-R     MINGUZZI, Andrea  ITA
# 29210  Beijing     2008  Wrestling  Wrestling Gre-R   KHUSHTOV, Aslanbek  RUS
# 29214  Beijing     2008  Wrestling  Wrestling Gre-R        LOPEZ, Mijain  CUB
#
# ...

# %%
df[(df.Medal == 'Gold') & (df.Gender == 'Women')]
# Out:
#            City  Edition          Sport       Discipline  \
# 417       Paris     1900           Golf             Golf
# 641       Paris     1900         Tennis           Tennis
# 649       Paris     1900         Tennis           Tennis
# 710    St Louis     1904        Archery          Archery
# 713    St Louis     1904        Archery          Archery
# ...         ...      ...            ...              ...
# 29134   Beijing     2008  Weightlifting    Weightlifting
# 29147   Beijing     2008      Wrestling  Wrestling Free.
# 29155   Beijing     2008      Wrestling  Wrestling Free.
# 29163   Beijing     2008      Wrestling  Wrestling Free.
# 29171   Beijing     2008      Wrestling  Wrestling Free.
#
#                      Athlete  NOC Gender  \
# 417    ABBOTT, Margaret Ives  USA  Women
# 641        COOPER, Charlotte  GBR  Women
# 649        COOPER, Charlotte  GBR  Women
# 710    HOWELL, Matilda Scott  USA  Women
# 713    HOWELL, Matilda Scott  USA  Women
# ...

# %% [markdown]
# String handling examples

# %%
df[df.Athlete.str.contains('Flo')]
# Out:
#                         City  Edition          Sport       Discipline  \
# 1843                  London     1908        Skating   Figure skating
# 1848                  London     1908        Skating   Figure skating
# 3775                 Antwerp     1920        Sailing          Sailing
# 4080                 Antwerp     1920  Weightlifting    Weightlifting
# 4173                   Paris     1924       Aquatics         Swimming
# 7376                  London     1948      Athletics        Athletics
# 8162                Helsinki     1952      Athletics        Athletics
# 8195                Helsinki     1952      Athletics        Athletics
# 8314                Helsinki     1952         Boxing           Boxing
# 9060   Melbourne / Stockholm     1956      Athletics        Athletics
# 10306                   Rome     1960       Football         Football
# 10849                  Tokyo     1964      Athletics        Athletics
# ...

# %%
df.head(1)
# Out:
#      City  Edition     Sport Discipline        Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming  HAJOS, Alfred  HUN    Men
#
#             Event Event_gender Medal
# 0  100m freestyle            M  Gold

# %%
jo = df[df.Athlete == 'OWENS, Jesse']

# %%
jo.Event.value_counts()
# Out:
# 100m            1
# 4x100m relay    1
# 200m            1
# long jump       1
# Name: Event, dtype: int64

# %%
counbad = df[(df.Medal == 'Gold') & (df.Gender == 'Men') & (df.Sport=='Badminton')]

# %%
counbad.sort_values(by='Athlete')
# Out:
#             City  Edition      Sport Discipline                  Athlete  NOC  \
# 20045  Barcelona     1992  Badminton  Badminton        BUDI KUSUMA, Alan  INA
# 23701     Sydney     2000  Badminton  Badminton            GUNAWAN, Tony  INA
# 25718     Athens     2004  Badminton  Badminton             HA, Tae-Kwon  KOR
# 25734     Athens     2004  Badminton  Badminton          HIDAYAT, Taufik  INA
# 21787    Atlanta     1996  Badminton  Badminton  HOYER-LARSEN, Poul Erik  DEN
# 23717     Sydney     2000  Badminton  Badminton              JI, Xinpeng  CHN
# 27725    Beijing     2008  Badminton  Badminton             KIDO, Markis  INA
# 25719     Athens     2004  Badminton  Badminton           KIM, Dong Moon  KOR
# 21773    Atlanta     1996  Badminton  Badminton           KIM, Dong Moon  KOR
# 20031  Barcelona     1992  Badminton  Badminton            KIM, Moon-Soo  KOR
# 27727    Beijing     2008  Badminton  Badminton             LEE, Yongdae  KOR
# ...

# %%
recent = df[df.Edition >= 1984]
recent.NOC.value_counts().head(3)
# Out:
# USA    1837
# AUS     762
# GER     691
# Name: NOC, dtype: int64

# %%
goldmhun = df[(df.Gender =='Men')& (df.Medal == 'Gold') &(df.Event == '100m') ]
goldmhun.sort_values(by='Edition', ascending =False)[['City','Edition','Athlete','NOC']]
# Out:
#                         City  Edition                Athlete  NOC
# 27552                Beijing     2008            BOLT, Usain  JAM
# 25539                 Athens     2004         GATLIN, Justin  USA
# 23521                 Sydney     2000        GREENE, Maurice  USA
# 21598                Atlanta     1996        BAILEY, Donovan  CAN
# 19859              Barcelona     1992      CHRISTIE, Linford  GBR
# 18284                  Seoul     1988            LEWIS, Carl  USA
# 16794            Los Angeles     1984            LEWIS, Carl  USA
# 15374                 Moscow     1980           WELLS, Allan  GBR
# 14069               Montreal     1976       CRAWFORD, Hasely  TRI
# 12902                 Munich     1972         BORZOV, Valery  URS
# 11865                 Mexico     1968       HINES, James Ray  USA
# 10823                  Tokyo     1964          HAYES, Robert  USA
# 9924                    Rome     1960            HARY, Armin  EUA
# ...

# %% [markdown]
# Indexing

# %%
ath = df.set_index('Athlete')
ath.head()
# Out:
#                     Edition Discipline  NOC Gender  \
# Athlete
# HAJOS, Alfred          1896   Swimming  HUN    Men
# HERSCHMANN, Otto       1896   Swimming  AUT    Men
# DRIVAS, Dimitrios      1896   Swimming  GRE    Men
# MALOKINIS, Ioannis     1896   Swimming  GRE    Men
# CHASAPIS, Spiridon     1896   Swimming  GRE    Men
#
#                                          Event Event_gender   Medal
# Athlete
# HAJOS, Alfred                   100m freestyle            M    Gold
# HERSCHMANN, Otto                100m freestyle            M  Silver
# DRIVAS, Dimitrios   100m freestyle for sailors            M  Bronze
# MALOKINIS, Ioannis  100m freestyle for sailors            M    Gold
# CHASAPIS, Spiridon  100m freestyle for sailors            M  Silver

# %%
ath.sort_index()
# Out:
#                           Edition   Discipline  NOC Gender  \
# Athlete
# AABYE, Edgar                 1900   Tug of War  ZZX    Men
# AALTONEN, Arvo Ossian        1920     Swimming  FIN    Men
# AALTONEN, Arvo Ossian        1920     Swimming  FIN    Men
# AALTONEN, Paavo Johannes     1948  Artistic G.  FIN    Men
# AALTONEN, Paavo Johannes     1948  Artistic G.  FIN    Men
# ...                           ...          ...  ...    ...
# ÖSTMO, Ole                   1900     Shooting  NOR    Men
# ÖSTMO, Ole                   1900     Shooting  NOR    Men
# ÖSTMO, Ole                   1900     Shooting  NOR    Men
# ÖSTMO, Ole                   1900     Shooting  NOR    Men
# ÖSTRAND, Per-Olof            1952     Swimming  SWE    Men
#
#                                                   Event Event_gender   Medal
# Athlete
# AABYE, Edgar                                 tug of war            M    Gold
# AALTONEN, Arvo Ossian                 200m breaststroke            M  Bronze
# ...

# %%
s = df.set_index('Event')
s
# Out:
#                             Edition       Discipline               Athlete  \
# Event
# 100m freestyle                 1896         Swimming         HAJOS, Alfred
# 100m freestyle                 1896         Swimming      HERSCHMANN, Otto
# 100m freestyle for sailors     1896         Swimming     DRIVAS, Dimitrios
# 100m freestyle for sailors     1896         Swimming    MALOKINIS, Ioannis
# 100m freestyle for sailors     1896         Swimming    CHASAPIS, Spiridon
# ...                             ...              ...                   ...
# 84 - 96kg                      2008  Wrestling Gre-R        ENGLICH, Mirko
# 96 - 120kg                     2008  Wrestling Gre-R  MIZGAITIS, Mindaugas
# 96 - 120kg                     2008  Wrestling Gre-R       PATRIKEEV, Yuri
# 96 - 120kg                     2008  Wrestling Gre-R         LOPEZ, Mijain
# 96 - 120kg                     2008  Wrestling Gre-R        BAROEV, Khasan
#
#                             NOC Gender Event_gender   Medal
# ...

# %%
s.loc['100m']
# Out:
#        Edition Discipline             Athlete  NOC Gender Event_gender   Medal
# Event
# 100m      1896  Athletics       LANE, Francis  USA    Men            M  Bronze
# 100m      1896  Athletics    SZOKOLYI, Alajos  HUN    Men            M  Bronze
# 100m      1896  Athletics       BURKE, Thomas  USA    Men            M    Gold
# 100m      1896  Athletics      HOFMANN, Fritz  GER    Men            M  Silver
# 100m      1900  Athletics     ROWLEY, Stanley  AUS    Men            M  Bronze
# ...        ...        ...                 ...  ...    ...          ...     ...
# 100m      2008  Athletics         BOLT, Usain  JAM    Men            M    Gold
# 100m      2008  Athletics   THOMPSON, Richard  TRI    Men            M  Silver
# 100m      2008  Athletics  FRASER, Shelly-ann  JAM  Women            W    Gold
# 100m      2008  Athletics    SIMPSON, Sherone  JAM  Women            W  Silver
# 100m      2008  Athletics     STEWART, Kerron  JAM  Women            W  Silver
#
# ...

# %%
df.loc[df.Athlete == 'BOLT, Usain']
# Out:
#            Edition Discipline      Athlete  NOC Gender         Event  \
# Sport
# Athletics     2008  Athletics  BOLT, Usain  JAM    Men          100m
# Athletics     2008  Athletics  BOLT, Usain  JAM    Men          200m
# Athletics     2008  Athletics  BOLT, Usain  JAM    Men  4x100m relay
#
#           Event_gender Medal
# Sport
# Athletics            M  Gold
# Athletics            M  Gold
# Athletics            M  Gold

# %%
df.iloc[1700]
# Out:
# Edition                  1908
# Discipline            Sailing
# Athlete         RABOT, Pierre
# NOC                       FRA
# Gender                    Men
# Event                      6m
# Event_gender                X
# Medal                  Bronze
# Name: Sailing, dtype: object

# %%
df.iloc[[1542, 2390,6000,15000]]
# Out:
#             Edition   Discipline                   Athlete  NOC Gender  \
# Sport
# Lacrosse       1908     Lacrosse    DUCKETT, Richard Louis  CAN    Men
# Gymnastics     1912  Artistic G.        SAASTAMOINEN, Eino  FIN    Men
# Fencing        1932      Fencing           AGOSTONI, Carlo  ITA    Men
# Sailing        1976      Sailing  JENSEN, Poul Richard Hoj  DEN    Men
#
#                                               Event Event_gender   Medal
# Sport
# Lacrosse                                   lacrosse            M    Gold
# Gymnastics                        team, free system            M  Silver
# Fencing                             épée individual            M  Bronze
# Sailing     fleet/match race keelboat open (Soling)            X    Gold

# %%
df.iloc[8:11]
# Out:
#           Edition Discipline                Athlete  NOC Gender  \
# Sport
# Aquatics     1896   Swimming  CHOROPHAS, Efstathios  GRE    Men
# Aquatics     1896   Swimming          NEUMANN, Paul  AUT    Men
# Aquatics     1896   Swimming      PEPANOS, Antonios  GRE    Men
#
#                    Event Event_gender   Medal
# Sport
# Aquatics  400m freestyle            M  Bronze
# Aquatics  400m freestyle            M    Gold
# Aquatics  400m freestyle            M  Silver

# %%
df.groupby('Edition')
type(df.groupby('Edition'))
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
for group_key, group_value in df.groupby('Edition'):
    print(group_key)
    print(group_value)
# Out:
# 1896
#                Edition       Discipline                   Athlete  NOC Gender  \
# Sport
# Aquatics          1896         Swimming             HAJOS, Alfred  HUN    Men
# Aquatics          1896         Swimming          HERSCHMANN, Otto  AUT    Men
# Aquatics          1896         Swimming         DRIVAS, Dimitrios  GRE    Men
# Aquatics          1896         Swimming        MALOKINIS, Ioannis  GRE    Men
# Aquatics          1896         Swimming        CHASAPIS, Spiridon  GRE    Men
# ...                ...              ...                       ...  ...    ...
# Weightlifting     1896    Weightlifting             JENSEN, Viggo  DEN    Men
# Weightlifting     1896    Weightlifting       ELLIOTT, Launceston  GBR    Men
# Wrestling         1896  Wrestling Gre-R  CHRISTOPOULOS, Stephanos  GRE    Men
# Wrestling         1896  Wrestling Gre-R            SCHUMANN, Carl  GER    Men
# Wrestling         1896  Wrestling Gre-R          TSITAS, Georgios  GRE    Men
#
# ...

# %%
df.groupby('Edition').size()
# Out:
# Edition
# 1896     151
# 1900     512
# 1904     470
# 1908     804
# 1912     885
# 1920    1298
# 1924     884
# 1928     710
# 1932     615
# 1936     875
# 1948     814
# 1952     889
# 1956     885
# 1960     882
# 1964    1010
# 1968    1031
# 1972    1185
# 1976    1305
# 1980    1387
# 1984    1459
# 1988    1546
# 1992    1705
# 1996    1859
# 2000    2015
# 2004    1998
# 2008    2042
# dtype: int64

# %%
df.groupby(['Edition','NOC','Medal']).size()
# Out:
# Edition  NOC  Medal
# 1896     AUS  Gold      2
#          AUT  Bronze    2
#               Gold      2
#               Silver    1
#          DEN  Bronze    3
#                        ..
# 2008     UZB  Silver    2
#          VEN  Bronze    1
#          VIE  Silver    1
#          ZIM  Gold      1
#               Silver    3
# Length: 2356, dtype: int64

# %%
df.groupby(['Edition','NOC','Medal']).agg({'Edition' :['min','max','count']})
# Out:
#                    Edition
#                        min   max count
# Edition NOC Medal
# 1896    AUS Gold      1896  1896     2
#         AUT Bronze    1896  1896     2
#             Gold      1896  1896     2
#             Silver    1896  1896     1
#         DEN Bronze    1896  1896     3
# ...                    ...   ...   ...
# 2008    UZB Silver    2008  2008     2
#         VEN Bronze    2008  2008     1
#         VIE Silver    2008  2008     1
#         ZIM Gold      2008  2008     1
#             Silver    2008  2008     3
#
# [2356 rows x 3 columns]

# %%
df.loc[df.Athlete == 'LEWIS, Carl'].groupby('Athlete').agg({'Edition' : ['min','max','count']})
# Out:
#             Edition
#                 min   max count
# Athlete
# LEWIS, Carl    1984  1996    10

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df.groupby('Edition').size().plot();

# %% [markdown]
# Create a list showing the total number of medals won for each country over the history of the Olympics. For each country, include the year of the first and most recent Olympic medal wins

# %%
df.groupby('NOC').agg({'Edition' : ['count','min','max']})
# Out:
#     Edition
#       count   min   max
# NOC
# AFG       1  2008  2008
# AHO       1  1988  1988
# ALG      14  1984  2008
# ANZ      29  1908  1912
# ARG     239  1924  2008
# ..      ...   ...   ...
# VIE       2  2000  2008
# YUG     435  1924  2000
# ZAM       2  1984  1996
# ZIM      23  1980  2008
# ZZX      48  1896  1904
#
# [138 rows x 3 columns]

# %%
mw = df[(df.Edition == 2008) & ( (df.Event == '100m') | (df.Event == '200m'))]
mw
# Out:
#            Edition Discipline                   Athlete  NOC Gender Event  \
# Sport
# Athletics     2008  Athletics               DIX, Walter  USA    Men  100m
# Athletics     2008  Athletics               BOLT, Usain  JAM    Men  100m
# Athletics     2008  Athletics         THOMPSON, Richard  TRI    Men  100m
# Athletics     2008  Athletics        FRASER, Shelly-ann  JAM  Women  100m
# Athletics     2008  Athletics          SIMPSON, Sherone  JAM  Women  100m
# Athletics     2008  Athletics           STEWART, Kerron  JAM  Women  100m
# Athletics     2008  Athletics               DIX, Walter  USA    Men  200m
# Athletics     2008  Athletics               BOLT, Usain  JAM    Men  200m
# Athletics     2008  Athletics           CRAWFORD, Shawn  USA    Men  200m
# Athletics     2008  Athletics           STEWART, Kerron  JAM  Women  200m
# Athletics     2008  Athletics  CAMPBELL-BROWN, Veronica  JAM  Women  200m
# Athletics     2008  Athletics            FELIX, Allyson  USA  Women  200m
# ...

# %%
g = mw.groupby(['NOC','Gender','Discipline','Event']).size()
g
# Out:
# NOC  Gender  Discipline  Event
# JAM  Men     Athletics   100m     1
#                          200m     1
#      Women   Athletics   100m     3
#                          200m     2
# TRI  Men     Athletics   100m     1
# USA  Men     Athletics   100m     1
#                          200m     2
#      Women   Athletics   200m     1
# dtype: int64

# %%
dfu = g.unstack(['Discipline','Event'])
dfu
# Out:
# Discipline Athletics
# Event           100m 200m
# NOC Gender
# JAM Men          1.0  1.0
#     Women        3.0  2.0
# TRI Men          1.0  NaN
# USA Men          1.0  2.0
#     Women        NaN  1.0

# %%
dfu.stack('Event')
# Out:
# Discipline        Athletics
# NOC Gender Event
# JAM Men    100m         1.0
#            200m         1.0
#     Women  100m         3.0
#            200m         2.0
# TRI Men    100m         1.0
# USA Men    100m         1.0
#            200m         2.0
#     Women  200m         1.0

# %%
dfu.unstack()
# Out:
# Discipline Athletics
# Event           100m       200m
# Gender           Men Women  Men Women
# NOC
# JAM              1.0   3.0  1.0   2.0
# TRI              1.0   NaN  NaN   NaN
# USA              1.0   NaN  2.0   1.0

# %% [markdown]
# Finding US athlete who has won the most total number of medals?

# %%
gy  = df[df.NOC == 'USA']
gy = gy.groupby(['Edition','Athlete','Medal']).size().unstack('Medal',fill_value=0)
gy['Total'] = gy['Gold'] + gy['Silver'] + gy['Bronze']
gy.reset_index(inplace=True)
tu = [group.sort_values('Total',ascending=False)[:1] for year,group in gy.groupby('Edition')]
tu
top = pd.DataFrame()
for i in tu:
    top = top.append(i)
top
# Out:
# Medal  Edition                      Athlete  Bronze  Gold  Silver  Total
# 5         1896              GARRETT, Robert       0     2       2      4
# 14        1900               BAXTER, Irving       0     2       3      5
# 153       1904                 HEIDA, Anton       0     5       1      6
# 363       1908             SHERIDAN, Martin       1     2       0      3
# 421       1912        OSBURN, Carl Townsend       1     1       2      4
# 506       1920                  LEE, Willis       1     5       1      7
# 733       1924          WEISSMULLER, Johnny       1     3       0      4
# 800       1928       OSIPOWICH, Albina Lucy       0     2       0      2
# 859       1932           DIDRIKSON, Mildred       0     2       1      3
# 1028      1936                 OWENS, Jesse       0     4       0      4
# 1128      1948      MCLANE, James Price Jr.       0     2       1      3
# 1234      1952          KONNO, Ford Hiroshi       0     2       1      3
# ...
